# %%
from sklearn.feature_extraction.text import TfidfVectorizer

documents = ["El gato juega", "El perro corre", "El gato y el perro corren"]
vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(documents)
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 10 stored elements and shape (3, 6)>

# %%
type(tfidf_matrix)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from sklearn.feature_extraction.text import CountVectorizer
documents = ["El perro ladra", "El gato maúlla"]

vectorizer = CountVectorizer()

bag_of_words = vectorizer.fit_transform(documents)
type(bag_of_words)
# Out:
# scipy.sparse._csr.csr_matrix

# %%
from nltk.stem import WordNetLemmatizer

# ERROR CALIFICAICION PUNTO 6

lemmatizer = WordNetLemmatizer()
words = ["cats", "running", "better"]
lemmatized_words = [lemmatizer.lemmatize(word) for word in words]
lemmatized_words
# Out:
# ['cat', 'running', 'better']

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
from nltk.stem import PorterStemmer

stemmer = PorterStemmer()
words = ["running", "runner", "ran", "runs"]
stemmed_words = [stemmer.stem(word) for word in words]
stemmed_words
# Out:
# ['run', 'runner', 'ran', 'run']

# %%
from nltk.tokenize import word_tokenize

text = "Estoy aprendiendo NLP."
# tokens = [f for f in text if f not in word_tokenize]
# tokens
word_tokenize.tokenize(text)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 6
#       3 text = "Estoy aprendiendo NLP."
#       4 # tokens = [f for f in text if f not in word_tokenize]
#       5 # tokens
# ----> 6 word_tokenize.tokenize(text)
#
# AttributeError: 'function' object has no attribute 'tokenize'

# %%
from nltk.corpus import stopwords

stop_words = set(stopwords.words('spanish'))
words = ["estoy", "aprendiendo", "nlp", "en", "python"]
filtered_words = [word for word in words if word not in stop_words]
filtered_words
# Out:
# ['aprendiendo', 'nlp', 'python']

# %%
from nltk.tokenize import word_tokenize

text = "La ciencia de datos es fascinante."

tokens = word_tokenize(text)
tokens
# Out:
# ['La', 'ciencia', 'de', 'datos', 'es', 'fascinante', '.']
